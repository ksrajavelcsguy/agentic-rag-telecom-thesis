# %%
from google.colab import drive
drive.mount("/content/drive")

import os
BASE_DIR = "/content/drive/MyDrive/agentic-rag-telecom-thesis"
os.makedirs(os.path.join(BASE_DIR, "data/raw"), exist_ok=True)

print("BASE_DIR =", BASE_DIR)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# BASE_DIR = /content/drive/MyDrive/agentic-rag-telecom-thesis

# %%
# Download Doc2Dial zip to Drive
import os
zip_path = os.path.join(BASE_DIR, "data/raw/doc2dial_v1.0.1.zip")
# !wget -O "{zip_path}" "https://doc2dial.github.io/file/doc2dial_v1.0.1.zip"
# !ls -lh "{zip_path}"
# Out:
# --2026-02-27 09:05:59--  https://doc2dial.github.io/file/doc2dial_v1.0.1.zip
# Resolving doc2dial.github.io (doc2dial.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to doc2dial.github.io (doc2dial.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6221970 (5.9M) [application/x-zip-compressed]
# Saving to: ‘/content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial_v1.0.1.zip’
#
# /content/drive/MyDr 100%[===================>]   5.93M  --.-KB/s    in 0.1s
#
# 2026-02-27 09:06:00 (40.3 MB/s) - ‘/content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial_v1.0.1.zip’ saved [6221970/6221970]
#
# -rw------- 1 root root 6.0M Apr 28  2022 /content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial_v1.0.1.zip

# %%
# Unzip into Drive
import os
out_dir = os.path.join(BASE_DIR, "data/raw/doc2dial")
os.makedirs(out_dir, exist_ok=True)

# !unzip -q "{zip_path}" -d "{out_dir}"
# !find "{out_dir}" -maxdepth 3 -type f | head -n 50
# Out:
# /content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial/DATA_README.md
# /content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial/__MACOSX/._DATA_README.md
# /content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial/__MACOSX/._doc2dial_dial_test.json
# /content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial/__MACOSX/._doc2dial_dial_train.json
# /content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial/__MACOSX/._doc2dial_dial_validation.json
# /content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial/__MACOSX/._doc2dial_doc.json
# /content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial/doc2dial_dial_test.json
# /content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial/doc2dial_dial_train.json
# /content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial/doc2dial_dial_validation.json
# /content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial/doc2dial_doc.json

# %%
import shutil, os
BASE_DIR = "/content/drive/MyDrive/agentic-rag-telecom-thesis"
macosx = os.path.join(BASE_DIR, "data/raw/doc2dial/__MACOSX")
if os.path.exists(macosx):
    shutil.rmtree(macosx)
print("Cleaned:", os.path.exists(macosx) == False)
# Out:
# Cleaned: True

# %%
import os
BASE_DIR = "/content/drive/MyDrive/agentic-rag-telecom-thesis"
mwz_drive_dir = os.path.join(BASE_DIR, "data/raw/multiwoz2.4")

if not os.path.exists(mwz_drive_dir):
    # !git clone https://github.com/smartyfh/MultiWOZ2.4 /content/multiwoz2.4
    # !mkdir -p "{mwz_drive_dir}"
    # !rsync -a /content/multiwoz2.4/ "{mwz_drive_dir}/"
    print("✅ MultiWOZ copied to Drive:", mwz_drive_dir)
else:
    print("✅ MultiWOZ already exists in Drive:", mwz_drive_dir)

# !ls -l "{mwz_drive_dir}" | head
# Out:
# Cloning into '/content/multiwoz2.4'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 109 (delta 48), reused 96 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (109/109), 27.39 MiB | 23.20 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# ✅ MultiWOZ copied to Drive: /content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/multiwoz2.4
# total 33
# -rw------- 1 root root 19692 Feb 27 09:07 create_data.py
# drwx------ 2 root root  4096 Feb 27 09:07 data
# -rw------- 1 root root  1078 Feb 27 09:07 LICENSE
# -rw------- 1 root root  1831 Feb 27 09:07 README.md
# -rw------- 1 root root  1296 Feb 27 09:07 split.py
# drwx------ 2 root root  4096 Feb 27 09:07 utils

# %%
# !mkdir -p configs

config_text = """\
project:
  name: agentic-rag-telecom-thesis
  run_id: "TBD-run-001"

data:
  # Drive paths (Colab)
  multiwoz_path: "/content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/multiwoz2.4"
  doc2dial_path: "/content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial"
  subset:
    enabled: true
    seed: 42
    dialogues: TBD
    documents: TBD

chunking:
  method: "recursive"
  chunk_size: TBD
  chunk_overlap: TBD

retrieval:
  vectorstore: "chroma"
  top_k: TBD
  score_threshold: TBD

models:
  path: "B"                 # non-API
  embedding_model: TBD       # e.g., all-MiniLM-L6-v2
  llm_model: TBD             # e.g., flan-t5-base (colab-friendly)

generation:
  temperature: 0.2
  max_tokens: 512

logging:
  save_traces: true
  traces_dir: "/content/drive/MyDrive/agentic-rag-telecom-thesis/results/traces"
"""

with open("configs/config.yaml", "w", encoding="utf-8") as f:
    f.write(config_text)

# !sed -n '1,60p' configs/config.yaml
# Out:
# project:
#   name: agentic-rag-telecom-thesis
#   run_id: "TBD-run-001"
#
# data:
#   # Drive paths (Colab)
#   multiwoz_path: "/content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/multiwoz2.4"
#   doc2dial_path: "/content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial"
#   subset:
#     enabled: true
#     seed: 42
#     dialogues: TBD
#     documents: TBD
#
# chunking:
#   method: "recursive"
#   chunk_size: TBD
#   chunk_overlap: TBD
#
# retrieval:
#   vectorstore: "chroma"
#   top_k: TBD
#   score_threshold: TBD
#
# models:
#   path: "B"                 # non-API
#   embedding_model: TBD       # e.g., all-MiniLM-L6-v2
#   llm_model: TBD             # e.g., flan-t5-base (colab-friendly)
#
# generation:
#   temperature: 0.2
#   max_tokens: 512
#
# logging:
#   save_traces: true
#   traces_dir: "/content/drive/MyDrive/agentic-rag-telecom-thesis/results/traces"

# %%
# !ls -l "/content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial/doc2dial_doc.json"
# !ls -l "/content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/multiwoz2.4/README.md"
# !ls -l "configs/config.yaml"
# Out:
# -rw------- 1 root root 46216432 Feb 26  2021 /content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/doc2dial/doc2dial_doc.json
# -rw------- 1 root root 1831 Feb 27 09:07 /content/drive/MyDrive/agentic-rag-telecom-thesis/data/raw/multiwoz2.4/README.md
# -rw-r--r-- 1 root root 828 Feb 27 09:07 configs/config.yaml
